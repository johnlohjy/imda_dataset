# %% [markdown]
# ## Example on using the dataset
#
# Resources on building the dataset
# - https://huggingface.co/datasets/AILAB-VNUHCM/vivos/blob/main/vivos.py
# - https://huggingface.co/docs/datasets/en/audio_dataset#loading-script
# - https://huggingface.co/docs/datasets/en/stream

# %% [markdown]
# Whenever changes are made to the dataset repo, run ```Remove-Item -Recurse -Force ~/.cache/huggingface/datasets/``` from the terminal

# %%
from datasets import load_dataset
dataset_repo = "johnlohjy/imda_nsc_testing"
dataset_train = load_dataset(dataset_repo, split='train', streaming=True, trust_remote_code=True)
dataset_test = load_dataset(dataset_repo, split='test', streaming=True, trust_remote_code=True)
# Out:
# Downloading builder script:   0%|          | 0.00/4.28k [00:00<?, ?B/s]

# %%
dataset_train_iter = iter(dataset_train)

# %%
print(next(dataset_train_iter))
# Out:
# {'path': 'train/waves/3000-1_1.wav', 'audio': {'path': 'train/waves/3000-1_1.wav', 'array': array([ 0.        , -0.00061035, -0.00094604, ...,  0.00054932,
#        -0.00048828, -0.00616455]), 'sampling_rate': 16000}, 'sentence': 'um you can go first'}

# %%
print(next(dataset_train_iter))
# Out:
# {'path': 'train/waves/3000-1_10.wav', 'audio': {'path': 'train/waves/3000-1_10.wav', 'array': array([ 0.00000000e+00,  0.00000000e+00, -3.05175781e-05, ...,
#         1.46484375e-03,  1.55639648e-03,  1.64794922e-03]), 'sampling_rate': 16000}, 'sentence': 'as an individual'}

# %%
print(next(dataset_train_iter))
# Out:
# {'path': 'train/waves/3000-1_100.wav', 'audio': {'path': 'train/waves/3000-1_100.wav', 'array': array([ 6.10351562e-05,  3.05175781e-05,  3.05175781e-05, ...,
#        -2.44140625e-04, -3.05175781e-05,  3.05175781e-05]), 'sampling_rate': 16000}, 'sentence': "okay let's say"}

# %%
dataset_test_iter = iter(dataset_test)

# %%
print(next(dataset_test_iter))
# Out:
# {'path': 'test/waves/3000-1_102.wav', 'audio': {'path': 'test/waves/3000-1_102.wav', 'array': array([ 9.15527344e-05, -6.10351562e-05, -2.13623047e-04, ...,
#        -1.22070312e-04, -1.52587891e-04, -1.22070312e-04]), 'sampling_rate': 16000}, 'sentence': 'ya'}

# %%
print(next(dataset_test_iter))
# Out:
# {'path': 'test/waves/3000-1_105.wav', 'audio': {'path': 'test/waves/3000-1_105.wav', 'array': array([-1.52587891e-04,  1.52587891e-04,  5.49316406e-04, ...,
#        -1.52587891e-04, -1.22070312e-04, -9.15527344e-05]), 'sampling_rate': 16000}, 'sentence': 'similarity that you find between you and'}

# %%
print(next(dataset_test_iter))
# Out:
# {'path': 'test/waves/3000-1_112.wav', 'audio': {'path': 'test/waves/3000-1_112.wav', 'array': array([ 3.05175781e-05,  0.00000000e+00,  3.05175781e-05, ...,
#         5.18798828e-04, -1.83105469e-04, -1.83105469e-04]), 'sampling_rate': 16000}, 'sentence': 'biggest difference between me and my parents'}

# %%
play_audio = next(dataset_test_iter)

# %%
from IPython.display import Audio
Audio(data=play_audio['audio']['array'], rate=play_audio['audio']['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
play_audio['sentence']
# Out:
# 'obviously to return the stuffs and you know not make a mess all over the table not litter the ground not litter the floor just help them out'

# %%
play_audio
# Out:
# {'path': 'test/waves/3000-1_117.wav',
#  'audio': {'path': 'test/waves/3000-1_117.wav',
#   'array': array([0.00036621, 0.00030518, 0.00024414, ..., 0.00137329, 0.00115967,
#          0.00088501]),
#   'sampling_rate': 16000},
#  'sentence': 'obviously to return the stuffs and you know not make a mess all over the table not litter the ground not litter the floor just help them out'}
